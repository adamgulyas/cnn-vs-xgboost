# %% [markdown]
# Imports

# %%
import os
from dotenv import load_dotenv
import numpy as np
import pandas as pd
import finnhub
import yfinance as yf
import talib as ta

# %% [markdown]
# Get dates for a ten-year window and convert to UNIX Timestamp integers

# %%
# Create datetime objects
end = pd.Timestamp("2022-08-01 23:59:00")
start = end - pd.Timedelta(days=365*10+2) # +2 leap days

# Convert datetime objects to UNIX timestamp
end_unix = int(pd.Timestamp.timestamp(end))
start_unix = int(pd.Timestamp.timestamp(start))

# %% [markdown]
# Get SPY data from FinnHub

# %%
# Connect to FinnHub API
load_dotenv()
finnhub_api_key = os.getenv('FINNHUB_API_KEY')
fh = finnhub.Client(api_key=finnhub_api_key)

# Note: price data is already adjusted by Finnhub
spy_ohlcv = fh.stock_candles('SPY', 'D', start_unix, end_unix)
spy_ohlcv = pd.DataFrame(spy_ohlcv)
spy_ohlcv.tail()
# Out:
#            c       h       l       o   s           t         v
# 2511  390.89  394.06  389.95  393.84  ok  1658793600  52946393
# 2512  401.04  402.88  394.05  394.36  ok  1658880000  82342106
# 2513  406.07  406.80  398.15  401.89  ok  1658966400  73966563
# 2514  411.99  413.03  406.77  407.58  ok  1659052800  87003672
# 2515  410.77  413.41  408.40  409.15  ok  1659312000  69997471

# %% [markdown]
# Check for nulls or missing data

# %%
# The `s` column indicates the response status
# Finnhub returns the string "no_data" for missing rows
spy_ohlcv.loc[spy_ohlcv['s'] == 'no_data']
# Out:
# Empty DataFrame
# Columns: [c, h, l, o, s, t, v]
# Index: []

# %%
# Check for any null rows
spy_ohlcv.isnull().values.any()
# Out:
# False

# %% [markdown]
# Convert UNIX timestamp to date objects and index the date

# %%
spy_ohlcv['date'] = pd.to_datetime(spy_ohlcv['t'], unit='s')
spy_ohlcv = spy_ohlcv.set_index(spy_ohlcv['date'])
spy_ohlcv.tail()
# Out:
#                  c       h       l       o   s           t         v  \
# date
# 2022-07-26  390.89  394.06  389.95  393.84  ok  1658793600  52946393
# 2022-07-27  401.04  402.88  394.05  394.36  ok  1658880000  82342106
# 2022-07-28  406.07  406.80  398.15  401.89  ok  1658966400  73966563
# 2022-07-29  411.99  413.03  406.77  407.58  ok  1659052800  87003672
# 2022-08-01  410.77  413.41  408.40  409.15  ok  1659312000  69997471
#
#                  date
# date
# 2022-07-26 2022-07-26
# 2022-07-27 2022-07-27
# 2022-07-28 2022-07-28
# 2022-07-29 2022-07-29
# 2022-08-01 2022-08-01

# %% [markdown]
# Drop columns and create the features DataFrame 'X'

# %%
X = spy_ohlcv.drop(columns=['s', 't', 'date'])
X.columns = ['close', 'high', 'low', 'open', 'volume']

# %% [markdown]
# Check dates

# %%
display(X.shape, X.head(), X.tail())
# Out:
# (2516, 5)
#               close    high       low    open     volume
# date
# 2012-08-01  137.590  138.73  137.4000  138.70  138293740
# 2012-08-02  136.640  137.57  135.5800  136.55  199556580
# 2012-08-03  139.349  139.64  136.6794  138.56  157824975
# 2012-08-06  139.620  140.17  139.5600  139.72   86327738
# 2012-08-07  140.320  140.92  140.0300  140.18  109545089
#              close    high     low    open    volume
# date
# 2022-07-26  390.89  394.06  389.95  393.84  52946393
# 2022-07-27  401.04  402.88  394.05  394.36  82342106
# 2022-07-28  406.07  406.80  398.15  401.89  73966563
# 2022-07-29  411.99  413.03  406.77  407.58  87003672
# 2022-08-01  410.77  413.41  408.40  409.15  69997471

# %% [markdown]
# Add technical analysis features to the DataFrame

# %%
close = X['close']
high = X['high']
low = X['low']

# Hilbert Transform - Instantaneous Trendline
X['trend'] = ta.HT_TRENDLINE(close)

# RSI
X['rsi'] = ta.RSI(close, timeperiod=20)

# Stochastic RSI
X['rsi_fast_k'], X['rsi_fast_d'] = ta.STOCHRSI(
    close, 
    timeperiod=14, 
    fastk_period=5, 
    fastd_period=3, 
    fastd_matype=0
)

# Williams' %R
X['williams_r'] = ta.WILLR(high, low, close, timeperiod=14)

# MACD, MACD Signal, MACD Histogram
X['macd'], X['macd_signal'], X['macd_hist'] = ta.MACD(
    close, 
    fastperiod=12, 
    slowperiod=26, 
    signalperiod=9
)

# Moving Averages
X['ma_20'] = ta.MA(close, timeperiod=20, matype=0)
X['ma_50'] = ta.MA(close, timeperiod=50, matype=0)
X['ma_65'] = ta.MA(close, timeperiod=65, matype=0)
X['ma_200'] = ta.MA(close, timeperiod=200, matype=0)

# Bollinger Bands
X['bb_upp'], X['bb_mid'], X['bb_low'] = ta.BBANDS(
    close, 
    timeperiod=5, 
    nbdevup=2, 
    nbdevdn=2, 
    matype=0
)

# Percentage Price Oscillator
X['ppo'] = ta.PPO(close, fastperiod=12, slowperiod=26, matype=0)

# Momentum
X['mom'] = ta.MOM(close, timeperiod=10)

# Rate of Change
X['roc'] = ta.ROC(close, timeperiod=10)

# Exponential Moving Averages
X['ema_20'] = ta.EMA(close, timeperiod=20)
X['ema_50'] = ta.EMA(close, timeperiod=50)
X['ema_65'] = ta.EMA(close, timeperiod=65)
X['ema_200'] = ta.EMA(close, timeperiod=200)

# %% [markdown]
# Get Indices data from Yahoo!

# %%
indices_ohlcv = yf.download('^GSPC ^NDX ^DJI ^DJT', start='2012-08-01', end='2022-08-02')
indices_close = indices_ohlcv['Adj Close']
indices_close.tail()
# Out:
# [*********************100%***********************]  4 of 4 completed
#                     ^DJI          ^DJT        ^GSPC          ^NDX
# Date
# 2022-07-26  31761.539062  13614.139648  3921.050049  12086.900391
# 2022-07-27  32197.589844  13847.009766  4023.610107  12601.469727
# 2022-07-28  32529.630859  14275.299805  4072.429932  12717.870117
# 2022-07-29  32845.128906  14609.000000  4130.290039  12947.969727
# 2022-08-01  32798.398438  14634.089844  4118.629883  12940.780273

# %% [markdown]
# Check for nulls

# %%
indices_close.isnull().values.any()
# Out:
# False

# %% [markdown]
# Format column Names

# %%
indices_close.columns = ['dji', 'djt', 'gspc', 'ndx']

# %% [markdown]
# Check shape and dates

# %%
display(indices_close.shape, indices_close.head(), indices_close.tail())
# Out:
# (2516, 4)
#                      dji          djt         gspc          ndx
# Date
# 2012-08-01  12976.129883  4986.709961  1375.319946  2635.129883
# 2012-08-02  12878.879883  4984.149902  1365.000000  2625.520020
# 2012-08-03  13096.169922  5086.310059  1390.989990  2676.000000
# 2012-08-06  13117.509766  5082.359863  1394.229980  2694.090088
# 2012-08-07  13168.599609  5092.459961  1401.349976  2717.159912
#                      dji           djt         gspc           ndx
# Date
# 2022-07-26  31761.539062  13614.139648  3921.050049  12086.900391
# 2022-07-27  32197.589844  13847.009766  4023.610107  12601.469727
# 2022-07-28  32529.630859  14275.299805  4072.429932  12717.870117
# 2022-07-29  32845.128906  14609.000000  4130.290039  12947.969727
# 2022-08-01  32798.398438  14634.089844  4118.629883  12940.780273

# %%
X.join(indices_close, on=X.index)
# Out:
#               close    high       low    open     volume       trend  \
# date
# 2012-08-01  137.590  138.73  137.4000  138.70  138293740         NaN
# 2012-08-02  136.640  137.57  135.5800  136.55  199556580         NaN
# 2012-08-03  139.349  139.64  136.6794  138.56  157824975         NaN
# 2012-08-06  139.620  140.17  139.5600  139.72   86327738         NaN
# 2012-08-07  140.320  140.92  140.0300  140.18  109545089         NaN
# ...             ...     ...       ...     ...        ...         ...
# 2022-07-26  390.890  394.06  389.9500  393.84   52946393  385.898000
# 2022-07-27  401.040  402.88  394.0500  394.36   82342106  386.804389
# 2022-07-28  406.070  406.80  398.1500  401.89   73966563  387.952778
# 2022-07-29  411.990  413.03  406.7700  407.58   87003672  389.536980
# 2022-08-01  410.770  413.41  408.4000  409.15   69997471  391.093075
#
#                   rsi  rsi_fast_k  rsi_fast_d  williams_r  ...    mom  \
# date                                                       ...
# 2012-08-01        NaN         NaN         NaN         NaN  ...    NaN
# 2012-08-02        NaN         NaN         NaN         NaN  ...    NaN
# 2012-08-03        NaN         NaN         NaN         NaN  ...    NaN
# 2012-08-06        NaN         NaN         NaN         NaN  ...    NaN
# 2012-08-07        NaN         NaN         NaN         NaN  ...    NaN
# ...               ...         ...         ...         ...  ...    ...
# 2022-07-26  49.785606    0.000000   34.261989  -31.880577  ...  10.06
# 2022-07-27  55.163433   98.608208   42.891288   -5.778894  ...  22.21
# 2022-07-28  57.535789  100.000000   66.202736   -2.041387  ...  28.16
# 2022-07-29  60.148111  100.000000   99.536069   -2.476780  ...  26.86
# 2022-08-01  59.356006   90.899678   96.966559   -6.230824  ...  28.82
#
#                  roc      ema_20      ema_50      ema_65     ema_200  \
# date
# 2012-08-01       NaN         NaN         NaN         NaN         NaN
# 2012-08-02       NaN         NaN         NaN         NaN         NaN
# 2012-08-03       NaN         NaN         NaN         NaN         NaN
# 2012-08-06       NaN         NaN         NaN         NaN         NaN
# 2012-08-07       NaN         NaN         NaN         NaN         NaN
# ...              ...         ...         ...         ...         ...
# 2022-07-26  2.641599  388.656472  394.164873  398.402067  418.154507
# 2022-07-27  5.862788  389.835856  394.434486  398.482005  417.984213
# 2022-07-28  7.451510  391.381965  394.890781  398.711944  417.865664
# 2022-07-29  6.974268  393.344635  395.561338  399.114309  417.807200
# 2022-08-01  7.545490  395.004193  396.157756  399.467512  417.737178
#
#                      dji           djt         gspc           ndx
# date
# 2012-08-01  12976.129883   4986.709961  1375.319946   2635.129883
# 2012-08-02  12878.879883   4984.149902  1365.000000   2625.520020
# 2012-08-03  13096.169922   5086.310059  1390.989990   2676.000000
# 2012-08-06  13117.509766   5082.359863  1394.229980   2694.090088
# 2012-08-07  13168.599609   5092.459961  1401.349976   2717.159912
# ...                  ...           ...          ...           ...
# 2022-07-26  31761.539062  13614.139648  3921.050049  12086.900391
# 2022-07-27  32197.589844  13847.009766  4023.610107  12601.469727
# 2022-07-28  32529.630859  14275.299805  4072.429932  12717.870117
# 2022-07-29  32845.128906  14609.000000  4130.290039  12947.969727
# 2022-08-01  32798.398438  14634.089844  4118.629883  12940.780273
#
# [2516 rows x 31 columns]

# %% [markdown]
# ### DataFrame Overview

# %%
print(X.shape)
display(X.head())
display(X.tail())
# Out:
# (2516, 27)
#               close    high       low    open     volume  trend  rsi  \
# date
# 2012-08-01  137.590  138.73  137.4000  138.70  138293740    NaN  NaN
# 2012-08-02  136.640  137.57  135.5800  136.55  199556580    NaN  NaN
# 2012-08-03  139.349  139.64  136.6794  138.56  157824975    NaN  NaN
# 2012-08-06  139.620  140.17  139.5600  139.72   86327738    NaN  NaN
# 2012-08-07  140.320  140.92  140.0300  140.18  109545089    NaN  NaN
#
#             rsi_fast_k  rsi_fast_d  williams_r  ...      bb_upp    bb_mid  \
# date                                            ...
# 2012-08-01         NaN         NaN         NaN  ...         NaN       NaN
# 2012-08-02         NaN         NaN         NaN  ...         NaN       NaN
# 2012-08-03         NaN         NaN         NaN  ...         NaN       NaN
# 2012-08-06         NaN         NaN         NaN  ...         NaN       NaN
# 2012-08-07         NaN         NaN         NaN  ...  141.441336  138.7038
#
#                 bb_low  ppo  mom  roc  ema_20  ema_50  ema_65  ema_200
# date
# 2012-08-01         NaN  NaN  NaN  NaN     NaN     NaN     NaN      NaN
# 2012-08-02         NaN  NaN  NaN  NaN     NaN     NaN     NaN      NaN
# 2012-08-03         NaN  NaN  NaN  NaN     NaN     NaN     NaN      NaN
# 2012-08-06         NaN  NaN  NaN  NaN     NaN     NaN     NaN      NaN
# 2012-08-07  135.966264  NaN  NaN  NaN     NaN     NaN     NaN      NaN
#
# [5 rows x 27 columns]
#              close    high     low    open    volume       trend        rsi  \
# date
# 2022-07-26  390.89  394.06  389.95  393.84  52946393  385.898000  49.785606
# 2022-07-27  401.04  402.88  394.05  394.36  82342106  386.804389  55.163433
# 2022-07-28  406.07  406.80  398.15  401.89  73966563  387.952778  57.535789
# 2022-07-29  411.99  413.03  406.77  407.58  87003672  389.536980  60.148111
# 2022-08-01  410.77  413.41  408.40  409.15  69997471  391.093075  59.356006
#
#             rsi_fast_k  rsi_fast_d  williams_r  ...      bb_upp   bb_mid  \
# date                                            ...
# 2022-07-26    0.000000   34.261989  -31.880577  ...  400.053078  395.022
# 2022-07-27   98.608208   42.891288   -5.778894  ...  403.200156  396.276
# 2022-07-28  100.000000   66.202736   -2.041387  ...  408.274580  397.732
# 2022-07-29  100.000000   99.536069   -2.476780  ...  416.028323  401.112
# 2022-08-01   90.899678   96.966559   -6.230824  ...  419.500644  404.152
#
#                 bb_low       ppo    mom       roc      ema_20      ema_50  \
# date
# 2022-07-26  389.990922  0.979949  10.06  2.641599  388.656472  394.164873
# 2022-07-27  389.351844  0.988895  22.21  5.862788  389.835856  394.434486
# 2022-07-28  387.189420  1.221374  28.16  7.451510  391.381965  394.890781
# 2022-07-29  386.195677  1.556088  26.86  6.974268  393.344635  395.561338
# 2022-08-01  388.803356  1.931096  28.82  7.545490  395.004193  396.157756
#
#                 ema_65     ema_200
# date
# 2022-07-26  398.402067  418.154507
# 2022-07-27  398.482005  417.984213
# 2022-07-28  398.711944  417.865664
# 2022-07-29  399.114309  417.807200
# 2022-08-01  399.467512  417.737178
#
# [5 rows x 27 columns]
